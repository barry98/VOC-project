# %%
import pandas as pd
import pandas as pd
import numpy as np
from tqdm import notebook
import ast
import re
from fuzzywuzzy import fuzz
from datetime import datetime, timedelta
import spacy
from sklearn.model_selection import train_test_split

# %%
def fleiss_kappa(ratings, n):
    '''
    Computes the Fleiss' kappa measure for assessing the reliability of 
    agreement between a fixed number n of raters when assigning categorical
    ratings to a number of items.
    
    Args:
        ratings: a list of (item, category)-ratings
        n: number of raters
        k: number of categories
    Returns:
        the Fleiss' kappa score
    
    See also:
        http://en.wikipedia.org/wiki/Fleiss'_kappa
    '''
    items = set()
    categories = set()
    n_ij = {}
    
    for i, c in ratings:
        items.add(i)
        categories.add(c)
        n_ij[(i,c)] = n_ij.get((i,c), 0) + 1
    
    N = len(items)
    
    p_j = dict(((c, sum(n_ij.get((i, c), 0) for i in items) / (1.0 * n * N)) for c in categories))
    P_i = dict(((i, (sum(n_ij.get((i, c), 0) ** 2 for c in categories) - n) / (n * (n - 1.0))) for i in items))

    P_bar = sum(P_i.values()) / (1.0 * N)
    P_e_bar = sum(value ** 2 for value in p_j.values())
    
    kappa = (P_bar - P_e_bar) / (1 - P_e_bar)
    
    return kappa

# %%
# ratings = [(1, 'yes')] * 10 + [(1, 'no')] * 0  + \
# [(2, 'yes')] * 8  + [(2, 'no')] * 2  + \
# [(3, 'yes')] * 9  + [(3, 'no')] * 1  + \
# [(4, 'yes')] * 0  + [(4, 'no')] * 10 + \
# [(5, 'yes')] * 7  + [(5, 'no')] * 3

fleiss_kappa(ratings, 4)
# Out:
# 0.35872058969924653

# %%
test_pat = pd.read_json('../../Annotation/Patrick/test_batch_patrick.json')

# %%
test_chiel = pd.read_json('../../Annotation/Chiel/test_batch_chiel.json')

# %%
ratings = []
for x in range(len(subset2_bar[0:554])):
    if subset2_bar.iloc[x].vocop_match == 0:
        ratings.append((x + 1, 'no'))
    else:
        ratings.append((x + 1, 'yes'))
    if subset2_bar.iloc[x].vocop_match == 0:
        ratings.append((x + 1, 'no'))
    else:
        ratings.append((x + 1, 'yes'))
    if test_pat.iloc[x].vocop_match == 0:
        ratings.append((x + 1, 'no'))
    else:
        ratings.append((x + 1, 'yes'))
    if test_chiel.iloc[x].vocop_match == 0:
        ratings.append((x + 1, 'no'))
    else:
        ratings.append((x + 1, 'yes'))

# %%
len(ratings)
# Out:
# 2216

# %%
((6**2) + (548**2) - 554) / (554 * (554 - 1))
# Out:
# 0.9785351969239005

# %%
pie = 0.9785351969239005 + 0.9785351969239005# + 0.971
pie = pie/2
pie
# Out:
# 0.9785351969239005

# %%
pce = ((6 + 6) / (2* 554)) ** 2 + ((548 + 548) / (2* 554)) ** 2 
print(pce)
(pie - pce) / (1-pce)
# Out:
# 0.9785739420558066
# -0.0018083182640071017

# %%
path = 'Completed Batches/'
subset1_pat = pd.read_json(path + 'batch1_patrick_result.json')
subset2_pat = pd.read_json(path + 'batch2_patrick_result.json')
subset3_pat = pd.read_json(path + 'batch3_patrick_result.json')
subset4_pat = pd.read_json(path + 'batch4_patrick_result.json')
subset5_pat = pd.read_json(path + 'batch5_patrick_result.json')
subset1_thom = pd.read_json(path + 'batch1_thom_result.json')
subset1_chiel = pd.read_json(path + 'batch1_chiel_result.json')
subset2_chiel = pd.read_json(path + 'batch2_chiel_result.json')
subset3_chiel = pd.read_json(path + 'batch3_chiel_result.json')
subset1_bar = pd.read_json(path + 'batch1_result.json')
subset2_bar = pd.read_json(path + 'result.json')
subset3_bar = pd.read_json(path + 'batch2_result.json')
subset4_bar = pd.read_json(path + 'batch3_result.json')
subset5_bar = pd.read_json(path + 'batch4_result.json')
subset6_bar = pd.read_json(path + 'batch2_thom_result.json')

# %%
len(subset2_bar[subset2_bar.vocop_match == 0])
# Out:
# 991

# %% [markdown]
# #### Correcties:
# Chiel:
# - Christiaan Andriesz 1416
# - Jan de Bruijn 1463
# - Abraham van de Heuvel (1823 super interessant twijfel geval)
# - Pieter van Essen (1825 super interessant twijfel geval)
# - Hans Pietersz 3792
#
# Patrick:
# - Jan Smit 4194 (zelde als de interessante gevallen van Chiel)
# - Hendrik van Alen 593 (zelfde schip maar naam is net even anders)

# %%
subset1_pat.at[593, 'vocop_match'] = 0
subset1_chiel.at[1416,'vocop_match'] = 0
subset1_chiel.at[1463,'vocop_match'] = 0
subset2_chiel.at[3729, 'vocop_match'] = 0
subset4_bar.at[9025, 'vocop_match'] = ('Johannis Oosterhoff', 140442)
subset5_bar.at[9927, 'vocop_match'] = ('Wiggert Andresz', 374198)
subset6_bar.at[2670, 'vocop_match'] = ('Johan Christiaan Richter', 379155)
subset6_bar.at[2688, 'vocop_match'] = ('Jacob Meijer', 178549)
subset6_bar.at[2689, 'vocop_match'] = ('Juriaan Bartels', 178548)
subset6_bar.at[2690, 'vocop_match'] = ('Willem Borsenius', 283179)
subset6_bar.at[2691, 'vocop_match'] = ('Jan de Vaij', 182941)

# %%
final_pat = subset1_pat
final_pat = final_pat.append(subset2_pat)
final_pat = final_pat.append(subset3_pat).append(subset4_pat).append(subset5_pat)

final_chiel = subset1_chiel
final_chiel = final_chiel.append(subset2_chiel)
final_chiel = final_chiel.append(subset3_chiel)

final_barry = subset1_bar
final_barry = final_barry.append(subset2_bar).append(subset3_bar).append(subset4_bar).append(subset5_bar).append(subset6_bar)

final_df = final_pat.append(final_chiel).append(subset1_thom).append(final_barry)

# %%
# final_df = final_df.loc[~final_df.index.duplicated(keep='first')]
# final_df.index.name = 'index'
# final_df.to_csv('../final_df.csv', index=True)
final_df[final_df.vocop_match != 0][50:101]#.uuid.value_counts()
# Out:
#                                        uuid  rubriek      notaris  \
# 1024   2179f9a4-6aff-a279-27b5-8637e2d71d67      358  JAN VERLEIJ
# 1032   df3ef34a-a719-033c-0f12-0f719913b3ac      358  JAN VERLEIJ
# 1131   b1867805-a5e1-7adb-6c53-436c6c7703f2      358  JAN VERLEIJ
# 1212   6eeff486-d429-f2ee-40f6-46bdfda3cbd6      358  JAN VERLEIJ
# 1321   a1cb3cb1-12d2-8848-b17d-d736777e0ad6      358  JAN VERLEIJ
# 5668   16106777-6e18-ce1d-f4a0-650fb3247e3a      358  JAN VERLEIJ
# 9927   \nschip Spaersaamheijd; schip 't Hoff d' Uno; ...
# 2642                               \nschip Huygenwaert\n
# 2669                 \nschip: Haerlem; schip: de Jager\n
# 2670                 \nschip: Haerlem; schip: de Jager\n
# 2688                      \nschip 't Huijs ter Duijnen\n
# 2689                      \nschip 't Huijs ter Duijnen\n
# 2690                      \nschip 't Huijs ter Duijnen\n
# 2691                      \nschip 't Huijs ter Duijnen\n
# 2749                              \nSchip de Immegonda\n
# 2834        \nschipper schip de Jager, VOC kamer Hoorn\n
# 2880                               \nschip Crabbendijk\n
# 3018               \nstuurman schip "Bloemendaal"  OIC\n
#
#                                                    namen  \
# 1024   [{'voornaam': 'Claas', 'tussenvoegsel': None, ...
# 1032   [{'voornaam': 'Fredrik', 'tussenvoegsel': None...
# 1131   [{'voornaam': 'Sijmen', 'tussenvoegsel': 'van'...
# 1212   [{'voornaam': 'Philip Lodewijk', 'tussenvoegse...
# 1321   [{'voornaam': 'Johan Hendrik', 'tussenvoegsel'...
# 5668   [{'voornaam': 'Jan', 'tussenvoegsel': None, 'a...
# 5687   [{'voornaam': 'Evert', 'tussenvoegsel': None, ...
# 5694   [{'voornaam': 'Cornelis', 'tussenvoegsel': 'de...
# 5846   [{'voornaam': 'Ernst August', 'tussenvoegsel':...
# 5857   [{'voornaam': 'Jan', 'tussenvoegsel': None, 'a...
# 5875   [{'voornaam': 'Willem', 'tussenvoegsel': None,...
# 5964   [{'voornaam': 'Pieter', 'tussenvoegsel': 'van'...
# 6001   [{'voornaam': 'Willem', 'tussenvoegsel': 'de',...
# 6044   [{'voornaam': 'Jacob', 'tussenvoegsel': None, ...
# 6072   [{'voornaam': 'Michiel', 'tussenvoegsel': None...
# 6106   [{'voornaam': 'Barend', 'tussenvoegsel': None,...
# 6190   [{'voornaam': 'Jurgen', 'tussenvoegsel': None,...
# 54430  [{'voornaam': 'Hendrik', 'tussenvoegsel': None...
# 54431  [{'voornaam': 'Hendrik', 'tussenvoegsel': None...
# 54459  [{'voornaam': 'Johan', 'tussenvoegsel': None, ...
# 54465  [{'voornaam': 'Cornelis', 'tussenvoegsel': Non...
# 54466  [{'voornaam': 'Cornelis', 'tussenvoegsel': Non...
# 54595  [{'voornaam': 'Johan', 'tussenvoegsel': None, ...
# 54707  [{'voornaam': 'Cornelis', 'tussenvoegsel': Non...
# 54741  [{'voornaam': 'Jacobus', 'tussenvoegsel': None...
# 55027  [{'voornaam': 'Jan', 'tussenvoegsel': None, 'a...
# 8438   [{'voornaam': 'Lucas', 'tussenvoegsel': None, ...
# 8920   [{'voornaam': 'Johan Fredrik', 'tussenvoegsel'...
# 9025   [{'voornaam': 'Willem', 'tussenvoegsel': 'de',...
# 9064   [{'voornaam': 'Magnus', 'tussenvoegsel': None,...
# 9253   [{'voornaam': 'Andries', 'tussenvoegsel': None...
# 9258   [{'voornaam': 'Nicolaas', 'tussenvoegsel': Non...
# 9337   [{'voornaam': 'Willem', 'tussenvoegsel': None,...
# 9347   [{'voornaam': 'Sebastiaan Jan', 'tussenvoegsel...
# 9359   [{'voornaam': 'Nicolaas', 'tussenvoegsel': Non...
# 9447   [{'voornaam': 'Jan', 'tussenvoegsel': 'van', '...
# 8920   [{'voornaam': 'Johan Fredrik', 'tussenvoegsel'...
# 9745   [{'voornaam': 'Johannes Francois', 'tussenvoeg...
# 9797   [{'voornaam': 'Pieter', 'tussenvoegsel': None,...
# 9927   [{'voornaam': 'Minne', 'tussenvoegsel': None, ...
# 2642   [{'voornaam': 'Christoffel', 'tussenvoegsel': ...
# 2669   [{'voornaam': 'Johan Christoffel', 'tussenvoeg...
# 2670   [{'voornaam': 'Johan Christoffel', 'tussenvoeg...
# 2688   [{'voornaam': 'Jacob', 'tussenvoegsel': None, ...
# 2689   [{'voornaam': 'Jacob', 'tussenvoegsel': None, ...
# 2690   [{'voornaam': 'Jacob', 'tussenvoegsel': None, ...
# 2691   [{'voornaam': 'Jacob', 'tussenvoegsel': None, ...
# 2749   [{'voornaam': 'Grietje', 'tussenvoegsel': None...
# 2834   [{'voornaam': 'Govert', 'tussenvoegsel': None,...
# 2880   [{'voornaam': 'Johan', 'tussenvoegsel': 'van',...
# 3018   [{'voornaam': 'Hendrik Coenraad', 'tussenvoegs...
#
#                                                     urls  \
# 1024      ['KLAB05443000151.JPG', 'KLAB05443000152.JPG']
# 1032   ['KLAB05443000454.JPG', 'KLAB05443000455.JPG',...
# 1131   ['KLAB05532000409.JPG', 'KLAB05532000410.JPG',...
# 1212   ['KLAB05523000511.JPG', 'KLAB05523000512.JPG',...
# 1321      ['KLAB05517000096.JPG', 'KLAB05517000097.JPG']
# 5668   ['KLAB06472000152.JPG', 'KLAB06472000153.JPG',...
# 5687   ['KLAB06472000078.JPG', 'KLAB06472000079.JPG',...
# 5694   ['KLAB06472000201.JPG', 'KLAB06472000202.JPG',...
# 5846      ['KLAB06471000222.JPG', 'KLAB06471000223.JPG']
# 5857   ['KLAB06471000251.JPG', 'KLAB06471000252.JPG',...
# 5875   ['KLAB06470000093.JPG', 'KLAB06470000094.JPG',...
# 5964   ['KLAB06468000354.JPG', 'KLAB06468000355.JPG',...
# 6001      ['KLAB06468000334.JPG', 'KLAB06468000335.JPG']
# 6044   ['KLAB06467000112.JPG', 'KLAB06467000113.JPG',...
# 6072   ['KLAB06467000295.JPG', 'KLAB06467000296.JPG',...
# 6106   ['KLAB06467000073.JPG', 'KLAB06467000074.JPG',...
# 6190   ['KLAB06693000219.JPG', 'KLAB06693000220.JPG',...
# 54430  ['KLAB05559000026.JPG', 'KLAB05559000027.JPG',...
# 54431  ['KLAB05559000026.JPG', 'KLAB05559000027.JPG',...
# 54459  ['KLAB05559000033.JPG', 'KLAB05559000034.JPG',...
# 54465     ['KLAB05559000102.JPG', 'KLAB05559000103.JPG']
# 54466     ['KLAB05559000102.JPG', 'KLAB05559000103.JPG']
# 54595  ['KLAB05516000182.JPG', 'KLAB05516000183.JPG',...
# 54707  ['KLAB05596000339.JPG', 'KLAB05596000340.JPG',...
# 54741  ['KLAB05596000257.JPG', 'KLAB05596000258.JPG',...
# 55027  ['KLAB05664000124.JPG', 'KLAB05664000125.JPG',...
# 8438   ['KLAB05516000196.JPG', 'KLAB05516000197.JPG',...
# 8920   ['KLAB05289000414.JPG', 'KLAB05289000415.JPG',...
# 9025      ['KLAB05664000317.JPG', 'KLAB05664000318.JPG']
# 9064   ['KLAB05664000509.JPG', 'KLAB05664000510.JPG',...
# 9253      ['KLAB05652000328.JPG', 'KLAB05652000329.JPG']
# 9258      ['KLAB05657000034.JPG', 'KLAB05657000035.JPG']
# 9337      ['KLAB05657000042.JPG', 'KLAB05657000043.JPG']
# 9347      ['KLAB05657000032.JPG', 'KLAB05657000033.JPG']
# 9359   ['KLAB05657000036.JPG', 'KLAB05657000037.JPG',...
# 9447   ['KLAB05616000119.JPG', 'KLAB05616000120.JPG',...
# 8920   ['KLAB05289000414.JPG', 'KLAB05289000415.JPG',...
# 9745   ['KLAB05777000075.JPG', 'KLAB05777000076.JPG',...
# 9797   ['KLAB05696000212.JPG', 'KLAB05696000213.JPG',...
# 9927   ['KLAB05718000156.JPG', 'KLAB05718000157.JPG',...
# 2642   ['KLAB05652000591.JPG', 'KLAB05652000592.JPG',...
# 2669   ['KLAB05652000160.JPG', 'KLAB05652000161.JPG',...
# 2670   ['KLAB05652000160.JPG', 'KLAB05652000161.JPG',...
# 2688      ['KLAB05652000523.JPG', 'KLAB05652000524.JPG']
# 2689      ['KLAB05652000523.JPG', 'KLAB05652000524.JPG']
# 2690      ['KLAB05652000523.JPG', 'KLAB05652000524.JPG']
# 2691      ['KLAB05652000523.JPG', 'KLAB05652000524.JPG']
# 2749   ['KLAB05657000441.JPG', 'KLAB05657000442.JPG',...
# 2834   ['KLAB05657000178.JPG', 'KLAB05657000179.JPG',...
# 2880   ['KLAB05657000615.JPG', 'KLAB05657000616.JPG',...
# 3018   ['KLAB05633000172.JPG', 'KLAB05633000173.JPG',...
#
#                                                     text  \
# 1024   No: 366 Procuratie gepasseert den 6e: Augustus...
# 1032   No: 461 Oblegdee gepasseert den 29 Sept: 17461...
# 1131   N55 Presnentie gecasseerd den 9 Dacomber 1746O...
# 1212   37 : 15No: 160 Sbteijate gepasseert den 24e: a...
# 1321   No: 390 Procuratie Grede den 22e: Feptem ber 1...
# 5668   No: 299 Procuratie gecasseerd den 23e: Octob: ...
# 5687   No: 276 Procuratie gecasseerd den 29e: Sept: 1...
# 5694   No: 314 Procuratie gecasseerd den 5e: navr: 17...
# 5846   en odt Conden de hem dezeegeld den 2Jeaf 1755 ...
# 5857   No: 195 Procuratie gecasseerd den 6e: Julij 17...
# 5875   No: 292 Procuratie gecasseerd den 21e: Sept: 1...
# 5964   an No: 215 Procuratie gecasseerd den 25e: aug:...
# 6001   No: 208 Procuratie gecasseerd den 12e: Aug: 17...
# 6044   No: 256 Procuratie gecasseerd den 30e: Sepp: 1...
# 6072   No: 311 Quitantie gecasseerd den 18 novr: 1766...
# 6106   3:5:51Eeeke Dit Testament van man en vrouw ver...
# 6190   No: 194 Procuratie passeert den 20e: Julij 176...
# 54430  No: 335 Procuratie gecasseerd den 9e: Sept: 17...
# 54431  No: 335 Procuratie gecasseerd den 9e: Sept: 17...
# 9359   Sebastiaan Jan van Meijers
# 9447             Jacobus Hamminga
# 8920           Minne Jansz Romijn
# 9745                Sijmen Simons
# 9797                 Pieter Green
# 9927              Wiggert Andries
# 2642             Christiaan Herts
# 2669       Johan Christoffel Rose
# 2670      Johan Christiaan Rigter
# 2688                 Jacob Meijer
# 2689             Jurriaan Bartels
# 2690             Willem Borzenius
# 2691                  Jan de Vrij
# 2749       Michiel Hendrik Kerken
# 2834             Jacob Leertouwen
# 2880        Johan van Veldhuijsen
# 3018                   Simon Smit
#
#                                             data_matches  \
# 1024   [{'index': 95444, 'name_original': 'Jan Haman'...
# 1032   [{'index': 48086, 'name_original': 'Hendrik La...
# 1131   [{'index': 67453, 'name_original': 'Pieter Sch...
# 1212   [{'index': 72145, 'name_original': 'Abraham Sw...
# 1321   [{'index': 80985, 'name_original': 'Johan Hend...
# 5668   [{'index': 88904, 'name_original': 'Jan Hagena...
# 5687   [{'index': 476312, 'name_original': 'Elias Sto...
# 5694   [{'index': 101246, 'name_original': 'Freedrik ...
# 5846   [{'index': 308820, 'name_original': 'Ernst Aug...
# 5857   [{'index': 5295, 'name_original': 'Jan Josephs...
# 5875   [{'index': 442099, 'name_original': 'Jan Wolte...
# 5964   [{'index': 55709, 'name_original': 'Hendrik Da...
# 6001   [{'index': 73206, 'name_original': 'Miechiel K...
# 6044   [{'index': 15438, 'name_original': 'Dirk Huijg...
# 6072   [{'index': 151, 'name_original': 'Jan Jansz.',...
# 6106   [{'index': 544574, 'name_original': 'Jan Hafka...
# 6190   [{'index': 6376, 'name_original': 'Jurien Muld...
# 54430  [{'index': 93879, 'name_original': 'Hendrik Vo...
# 54431  [{'index': 338809, 'name_original': 'Goosen Gr...
# 54459  [{'index': 125788, 'name_original': 'Jan Stend...
# 54465  [{'index': 33017, 'name_original': 'Cornelis V...
# 54466  [{'index': 21034, 'name_original': 'Jan Govers...
# 54595  [{'index': 3138, 'name_original': 'Hendrick Bu...
# 54707  [{'index': 114308, 'name_original': 'Cornelis ...
# 54741  [{'index': 73130, 'name_original': 'Fredrik Wa...
# 55027  [{'index': 415, 'name_original': 'Jan Held', '...
# 8438   [{'index': 176077, 'name_original': 'Jurgen Fl...
# 8920   [{'index': 284657, 'name_original': 'Minne Jan...
# 9025   [{'index': 140442, 'name_original': 'Johannis ...
# 9064   [{'index': 507790, 'name_original': 'Magnus So...
# 9253   [{'index': 25108, 'name_original': 'Andries Br...
# 9258   [{'index': 539401, 'name_original': 'Sebastiaa...
# 9337   [{'index': 383874, 'name_original': 'Pieter We...
# 9347   [{'index': 539401, 'name_original': 'Sebastiaa...
# 9359   [{'index': 539401, 'name_original': 'Sebastiaa...
# 9447   [{'index': 177843, 'name_original': 'Jacobus H...
# 8920   [{'index': 284657, 'name_original': 'Minne Jan...
# 9745   [{'index': 14544, 'name_original': 'Seijmon Se...
# 9797   [{'index': 5084, 'name_original': 'Pieter Groe...
# 9927   [{'index': 39910, 'name_original': 'Wiggert An...
# 2642   [{'index': 11027, 'name_original': 'Christiaan...
# 2669   [{'index': 73153, 'name_original': 'Johan Chri...
# 2670   [{'index': 39258, 'name_original': 'Johan Chri...
# 2688   [{'index': 3468, 'name_original': 'Jacob Meije...
# 2689   [{'index': 178548, 'name_original': 'Juriaan B...
# 2690   [{'index': 283179, 'name_original': 'Willem Bo...
# 2691   [{'index': 275, 'name_original': 'Jan de Vries...
# 2749   [{'index': 297296, 'name_original': 'Michiel H...
# 2834   [{'index': 268969, 'name_original': 'Jacob Lee...
# 2880   [{'index': 418944, 'name_original': 'Johan van...
# 3018   [{'index': 144359, 'name_original': 'Simon Smi...
#
#                                               data_entry  \
# 1024   {'95444': {'ships': [], 'rank': [], 'location'...
# 1032   {'48086': {'ships': [], 'rank': [], 'location'...
# 1131   {'67453': {'ships': [], 'rank': [], 'location'...
# 1212   {'72145': {'ships': [], 'rank': [], 'location'...
# 1321   {'80985': {'ships': [], 'rank': [], 'location'...
# 5668   {'88904': {'ships': [], 'rank': [], 'location'...
# 5687   {'476312': {'ships': [], 'rank': [], 'location...
# 5694   {'101246': {'ships': ['Kattendijke', 'VROUWE E...
# 5846   {'308820': {'ships': [], 'rank': [], 'location...
# 5857   {'5295': {'ships': [], 'rank': [], 'location':...
# 5875   {'442099': {'ships': ['Getrouwigheid', 'JERUSA...
# 5964   {'55709': {'ships': [], 'rank': [], 'location'...
# 6001   {'73206': {'ships': ['Noord Nieuwland', 'SCHOO...
# 6044   {'15438': {'ships': [], 'rank': [], 'location'...
# 6072   {'151': {'ships': [], 'rank': [], 'location': ...
# 6106   {'544574': {'ships': ['nan'], 'rank': [], 'loc...
# 6190   {'6376': {'ships': [], 'rank': [], 'location':...
# 54430  {'93879': {'ships': [], 'rank': [], 'location'...
# 54431  {'338809': {'ships': ['Akerendam', 'AKERENDAM'...
# 54459  {'125788': {'ships': ['Nieuw Walcheren', 'KRAB...
# 54465  {'33017': {'ships': [], 'rank': [], 'location'...
# 54466  {'21034': {'ships': [], 'rank': [], 'location'...
# 54595  {'3138': {'ships': [], 'rank': [], 'location':...
# 54707  {'114308': {'ships': [], 'rank': [], 'location...
# 54741  {'73130': {'ships': [], 'rank': [], 'location'...
# 55027  {'415': {'ships': [], 'rank': [], 'location': ...
# 8438   {'176077': {'ships': ['Duinenburg', 'HUIS TER ...
# 8920   {'284657': {'ships': [], 'rank': [], 'location...
# 9025   {'140442': {'ships': ['Baarzande', 'BAARZANDE'...
# 9064   {'507790': {'ships': ['Luxemburg'], 'rank': ['...
# 9253   {'25108': {'ships': [], 'rank': [], 'location'...
# 9258   {'539401': {'ships': [], 'rank': ['Raad van Ju...
# 9337   {'383874': {'ships': [], 'rank': [], 'location...
# 9347   {'539401': {'ships': ['nan'], 'rank': ['Raad v...
# 9359   {'539401': {'ships': [], 'rank': ['Raad van Ju...
# 9447   {'177843': {'ships': [], 'rank': [], 'location...
# 8920   {'284657': {'ships': [], 'rank': [], 'location...
# 9745   {'14544': {'ships': [], 'rank': [], 'location'...
# 9797   {'5084': {'ships': [], 'rank': [], 'location':...
# 9927   {'39910': {'ships': [], 'rank': [], 'location'...
# 2642   {'11027': {'ships': [], 'rank': [], 'location'...
# 2669   {'73153': {'ships': [], 'rank': [], 'location'...
# 2670   {'39258': {'ships': [], 'rank': [], 'location'...
# 2688   {'3468': {'ships': [], 'rank': [], 'location':...
# 2689   {'178548': {'ships': ['Huis ter Duine', 'HUIS ...
# 2690   {'283179': {'ships': ['HUIS TER DUINE'], 'rank...
# 2691   {'275': {'ships': [], 'rank': [], 'location': ...
# 2749   {'297296': {'ships': [], 'rank': [], 'location...
# 2834   {'268969': {'ships': [], 'rank': [], 'location...
# 2880   {'418944': {'ships': ['Krabbendijke'], 'rank':...
# 3018   {'144359': {'ships': [], 'rank': [], 'location...
#
#                                 vocop_match
# 1024                  [Jan Haveman, 310678]
# 1032             [Hendrik de Lange, 329199]
# 1131               [Pieter Schriek, 327723]
# 1212                [Abraham Swart, 338951]
# 1321           [Johan Hendrik Haze, 259917]
# 5668                  [Jan Hagenau, 457173]
# 5687                [Elias Stodius, 493407]
# 5694                [Freedrik Hove, 101246]
# 5846     [Ernst Augustus Berkelman, 447428]
# 5857                    [Jan Joseph, 81104]
# 5875            [Jan Wolter Visser, 442099]
# 5964                 [Hendrik Dames, 80776]
# 6001               [Miechiel Komber, 73206]
# 6044                  [Dirk Huijer, 112348]
# 6072                   [Jan Jansen, 109003]
# 6106                  [Jan Hafkamp, 544574]
# 6190                [Jurgen Mulder, 497081]
# 54430             [Hendrik Volkers, 365319]
# 54431           [Goosen Groenhuijs, 338809]
# 54459                 [Jan Stender, 125788]
# 54465                 [Cornelis Vis, 66931]
# 54466                [Jan Govertsz., 66979]
# 54595             [Hendrik Burgers, 297772]
# 54707              [Cornelis Oberg, 367003]
# 54741          [Fredrik Saalstroom, 419018]
# 55027                    [Jan Helt, 461061]
# 8438               [Jurgen Fleuger, 176077]
# 8920          [Minne Jansz Romeijn, 459834]
# 9025          (Johannis Oosterhoff, 140442)
# 9064              [Magnus Sondberg, 507790]
# 9253               [Andries Bouman, 182708]
# 9258   [Sebastiaan Jan van Meijers, 539401]
# 9337              [Pieter Westmark, 434463]
# 9347   [Sebastiaan Jan van Meijers, 539401]
# 9359   [Sebastiaan Jan van Meijers, 539401]
# 9447             [Jacobus Hamminga, 489594]
# 8920          [Minne Jansz Romeijn, 459834]
# 9745               [Sijmen Simonsz, 423328]
# 9797                 [Pieter Green, 352088]
# 9927              (Wiggert Andresz, 374198)
# 2642             [Christiaen Herts, 375729]
# 2669      [Johan Christoffel Roode, 284399]
# 2670     (Johan Christiaan Richter, 379155)
# 2688                 (Jacob Meijer, 178549)
# 2689              (Juriaan Bartels, 178548)
# 2690             (Willem Borsenius, 283179)
# 2691                  (Jan de Vaij, 182941)
# 2749        [Michiel Hendrik Kerke, 409527]
# 2834             [Jacob Leertouwer, 311020]
# 2880        [Johan van Velthuijsen, 418944]
# 3018                   [Simon Smit, 396195]

# %%
final_df.loc[5687].data_matches
# Out:
# [{'index': 476312,
#   'name_original': 'Elias Stodius',
#   'name_normalized': 'Elias Stodius',
#   'date_out': '1760-03-26',
#   'date_return': '1762-06-24',
#   'ship_out': 'Bosschenhove',
#   'ship_return': 'ZUID-BEVELAND',
#   'rank': 'Bosschieter',
#   'place_of_origin': 'Stokholm'},
#  {'index': 489721,
#   'name_original': 'Elias Stodius',
#   'name_normalized': 'Elias Stodius',
#   'date_out': '1754-11-02',
#   'date_return': '1757-08-14',
#   'ship_out': 'Herstelder',
#   'ship_return': 'LUXEMBURG',
#   'rank': 'Matroos',
#   'place_of_origin': 'Stokkolm'},
#  {'index': 493407,
#   'name_original': 'Elias Stodius',
#   'name_normalized': 'Elias Stodius',
#   'date_out': '1762-10-31',
#   'date_return': '1764-07-27',
#   'ship_out': 'Westerveld',
#   'ship_return': 'WESTERVELD',
#   'rank': 'Kwartiermeester',
#   'place_of_origin': 'Stokholm'},
#  {'index': 525806,
#   'name_original': 'Elias Stodlius',
#   'name_normalized': 'Elias Stodlius',
#   'date_out': '1757-12-30',
#   'date_return': '1759-10-03',
#   'ship_out': 'Renswoude',
#   'ship_return': 'RENSWOUDE',
#   'rank': 'Bosschieter',
#   'place_of_origin': 'Stokholm'},
#  {'index': 586155,
#   'name_original': 'Elias Stodius',
#   'name_normalized': 'Elias Stodius',
#   'date_out': '1765-06-18',
#   'date_return': '1767-07-17',
#   'ship_out': 'Nieuw Nieuwerkerk',
#   'ship_return': None,
#   'rank': 'Konstabel',
#   'place_of_origin': 'Stokholm'}]

# %%
nlp = spacy.load('nl_core_news_sm', disable=['parser', 'tagger', 'textcat'])

# %%
def match_neighbour(start, end, true, prev, distance):
    if true == []:
        return (start, end), prev.i
    if prev.i == len(prev.doc) - 1:
        return (start, end), prev.i
    if fuzz.ratio(true[0].lower(), prev.nbor().text.lower()) >= distance:
        return match_neighbour(start, prev.nbor().idx + len(prev.nbor()), true[1:], prev.nbor(), distance)
    else:
        return (start, end), prev.i

def match_finder(row, match, distance):

    true = match
    doc = nlp(row.text)
    locs = []
    prev = 0
    for token in doc:
            for x in true:
                if token.i > prev and type(x) == str:
                    split = x.split(' ')
                    if fuzz.ratio(split[0].lower(), token.text.lower()) >= distance:
                        result, prev = match_neighbour(token.idx, token.idx + len(token), split[1:], token, distance)
                        if result not in locs:
                            if fuzz.ratio(row.text[result[0]:result[1]], x) >= distance:
                                locs.append(result)
    entities = [row.text[x[0]:x[1]] for x in locs]
    return entities

def fix_entries_ships(row, x):
    ships = match_finder(row, [x['shipOutward'], x['shipReturn']], 80)
    rank =  match_finder(row, [x['dutch_rank']], 80)
    location = match_finder(row, [x['placeOfOrigin']], 90)
#     keywords = match_finder(row, ['kamer van zeeland', 'kamer zeeland', 'kamer van amsterdam', 'kamer amsterdam', 
#                                   'kamer van hoorn', 'kamer hoorn', 'kamer enkhuizen', 'kamer van enkhuizen',
#                                   'kamer delft', 'kamer van delft', 'oostindische compagnie', 'oostindie compagnie',
#                                   'oostindie'], 80)
    true_data_matches = {'ships': ships, 'location':location, 'rank':rank}#, 'keywords':keywords}
    return true_data_matches

# %%
voc = pd.read_csv('../vocop_clustered_dutchrank.csv')
# Out:
# D:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (17,27,35,36,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ranking_df = pd.DataFrame(columns=['name_ratio', 'name_count', 'day_dif', 'location', 'rank', 'numships', 'keywords', 'match', 'notary_id', 'voc_id'])
name_dict = voc.fullNameNormalized.value_counts()
for x in notebook.tqdm(final_df[final_df.data_matches != 0].itertuples(), total=final_df[final_df.data_matches != 0].shape[0]):
    notary_date = datetime.strptime(x.datering, '%Y-%m-%d')
    notid = x.Index
    for match in x.data_matches:
        index = str(x.Index) + '_' + str(match['index'])
        vocid=match['index']
        name_ratio=max(fuzz.ratio(x.name, match['name_original']), fuzz.ratio(x.name, match['name_normalized']))
        name_count = name_dict[match['name_normalized']]
        
        if x.vocop_match != 0 and match['index'] == x.vocop_match[1]:
            matched = 1
        else:
            matched = 0
        
        try:
            out_date = datetime.strptime(match['date_out'], '%Y-%m-%d')
        except:
            out_date = datetime(year=1, month=1, day =1 )
        try:
            return_date = datetime.strptime(match['date_return'], '%Y-%m-%d')
        except:
            return_date = datetime(year=1, month=1, day =1 )
        if (notary_date - out_date).days in range(0, -91, -1):
            day_dif = -(notary_date - out_date).days
        elif (notary_date - return_date).days in range(0, 91):
            day_dif = (notary_date - return_date).days
        else:
            continue
        
        
        if str(match['index']) in x.data_entry:
            ship_matches = fix_entries_ships(x, match)
            numships = len(ship_matches['ships'])
            if ship_matches['rank'] != []:
                rank = 1
            else:
                rank = 0
            if ship_matches['location'] != []:
                location = 1
            else:
                location = 0
            if ship_matches['keywords'] != []:
                keywords = 1
            else:
                keywords = 0
        else:
            numships = 0
            rank = 0
            location = 0
        tempdf = pd.DataFrame(columns=['name_ratio', 'name_count', 'day_dif', 'location', 'rank', 'numships', 'keywords', 'match', 'notary_id', 'voc_id'], data={
            'name_ratio':name_ratio,
            'name_count':name_count,
            'day_dif':day_dif, 
            'location':location,
            'rank':rank,
            'numships':numships,
            'keywords':keywords,
            'match':matched,
            'notary_id':notid,
            'voc_id':vocid
        }, index=[index])
        ranking_df = ranking_df.append(tempdf)
# Out:
# HBox(children=(IntProgress(value=0, max=5402), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-147-868ffd0cb968> in <module>
#      32
#      33         if str(match['index']) in x.data_entry:
# ---> 34             ship_matches = fix_entries_ships(x, match)
#      35             numships = len(ship_matches['ships'])
#      36             if ship_matches['rank'] != []:
#
# <ipython-input-146-ba3b13e0fa7b> in fix_entries_ships(row, x)
#      28
#      29 def fix_entries_ships(row, x):
# ---> 30     ships = match_finder(row, [x['shipOutward'], x['shipReturn']], 80)
#      31     rank =  match_finder(row, [x['dutch_rank']], 80)
#      32     location = match_finder(row, [x['placeOfOrigin']], 90)
#
# KeyError: 'shipOutward'

# %%
ranking_df.to_csv('../preranking.csv', index=False)
#final_df.to_csv('../final_df.csv')
#ranking_df[ranking_df.match == 1]

# %%
train, test = train_test_split(final_df, test_size=0.3, random_state=10)

# %%
def match_neighbour(start, end, true, prev, distance):
    if true == []:
        return (start, end), prev.i
    if prev.i == len(prev.doc) - 1:
        return (start, end), prev.i
    if fuzz.ratio(true[0].lower(), prev.nbor().text.lower()) >= distance:
        return match_neighbour(start, prev.nbor().idx + len(prev.nbor()), true[1:], prev.nbor(), distance)
    else:
        return (start, end), prev.i

def match_finder(row, match, distance):

    true = match
    doc = nlp(row.text)
    locs = []
    prev = 0
    for token in doc:
        for x in true:
            if type(x) == str:
                new_token = []
                split = x.split(' ')
                for y in range(len(split)):
                    if token.i <= doc[-len(split)].i:
                        new_token.append(token.nbor(y).text)
                new_token_text = ' '.join(new_token)
                if fuzz.ratio(x.lower(), new_token_text.lower()) >= distance:
                    result = (token.idx, token.idx + len(new_token_text))
                    if result not in locs:
                        if fuzz.ratio(row.text[result[0]:result[1]].lower(), x.lower()) >= distance:
                            locs.append(result)
    entities = [row.text[x[0]:x[1]] for x in locs]
    return entities

def fix_entries_ships(row, x, column):
    if type(x[column]) != float: 
        match = match_finder(row, [x[column]], 80) 
    else:
        match = ''
    return match

# %%
match_finder(final_df.loc[2690],['Huis ter Duine'], 80)
# Out:
# ['huijs ten Duijnen']

# %%
final_df.loc[3171]
# Out:
# uuid                         cfbda433-0688-d920-1e4c-541ac73e3904
# rubriek                                                       358
# notaris                                               JAN VERLEIJ
# inventarisNr                                                11920
# akteNr                                                      15508
# akteType                                               Machtiging
# datering                                               1753-05-17
# taal                                                   nederlands
# beschrijving            \nOpperstuurman schip "Voorzigtigheijd"\n
# namen           [{'voornaam': 'Jan Fredrik', 'tussenvoegsel': ...
# urls            ['KLAB05777000066.JPG', 'KLAB05777000067.JPG',...
# text            Bo:169 Procuratie gecasseerd den 17e: Maij 175...
# name                                        Jan Fredrik Schrijver
# data_matches    [{'index': 179622, 'name_original': 'Jan Fredr...
# data_entry      {'179622': {'ships': [], 'rank': [], 'location...
# vocop_match                       [Jan Fredrik Schrijver, 180810]
# Name: 3171, dtype: object

# %% [markdown]
# ## Dedupe Record Linking

# %%
data_n = {}
data_v = {}
df = train
for x in notebook.tqdm(range(len(df))):
    row = df.iloc[x]
    holder = []
    if row.data_matches != 0:
        notary_date = datetime.strptime(row.datering, '%Y-%m-%d')
        
        for match in row.data_matches:
            try:
                out_date = datetime.strptime(match['date_out'], '%Y-%m-%d')
            except:
                out_date = datetime(year=1, month=1, day =1 )
            try:
                return_date = datetime.strptime(match['date_return'], '%Y-%m-%d')
            except:
                return_date = datetime(year=1, month=1, day =1 )
            if (notary_date - out_date).days in range(0, -91, -1):
                day_dif = -(notary_date - out_date).days
            elif (notary_date - return_date).days in range(0, 91):
                day_dif = (notary_date - return_date).days
            else:
                continue
            
            found_ship_out = fix_entries_ships(row, voc.iloc[match['index']], 'shipOutward')
            found_ship_return = fix_entries_ships(row, voc.iloc[match['index']], 'shipReturn')
            found_loc = fix_entries_ships(row, voc.iloc[match['index']], 'placeOfOrigin')
            found_rank = fix_entries_ships(row, voc.iloc[match['index']], 'dutch_rank')
            holder.append({'rank':found_rank, 'location':found_loc, 'found_ship_return': found_ship_return, 'found_ship_out': found_ship_out})
            
            if row.vocop_match != 0 and match['index'] == row.vocop_match[1]:
                cluster = df.iloc[x].name
            else:
                cluster = -int(voc.iloc[match['index']].VOCOP_id)
            name = str(voc.iloc[match['index']].fullNameOriginal)
            rang = str(voc.iloc[match['index']].dutch_rank)
            loc = str(voc.iloc[match['index']].placeOfOrigin)
            ship_out = str(voc.iloc[match['index']].shipOutward) 
            ship_return = str(voc.iloc[match['index']].shipReturn)
            data_v[-int(voc.iloc[match['index']].VOCOP_id)] = {'cluster_id': cluster, 'name':name, 'rank':rang, 'location':loc, 'ship_out': ship_out, 'ship_return': ship_return}
    name = row['name']
    if holder == []:
        rang = None
        location = None
        ship_out= None
        ship_return = None
    
    else:
        rang = ' | '.join(set([y.lower() for x in holder for y in x['rank']]))
        if rang == '':
            rang = None
        location = ' | '.join(set([y.lower() for x in holder for y in x['location']]))
        if location == '':
            location = None
        ship_out = ' | '.join(set([y.lower() for x in holder for y in x['found_ship_out']]))
        if ship_out == '':
            ship_return = None
        ship_return = ' | '.join(set([y.lower() for x in holder for y in x['found_ship_return']]))
        if ship_return == '':
            ship_return = None
    data_n[df.iloc[x].name] = {'cluster_id': df.iloc[x].name, 'name':name, 'rank':rang, 'location':location, 'ship_out': ship_out, 'ship_return': ship_return}

d_n = {'cluster_id': [data_n[x]['cluster_id'] for x in data_n], 'name': [data_n[x]['name'] for x in data_n], 'rank':[data_n[x]['rank'] for x in data_n],
     'location':[data_n[x]['location'] for x in data_n], 'ship_out': [data_n[x]['ship_out'] for x in data_n], 'ship_return': [data_n[x]['ship_return'] for x in data_n]}

d_v = {'cluster_id': [data_v[x]['cluster_id'] for x in data_v], 'name': [data_v[x]['name'] for x in data_v], 'rank':[data_v[x]['rank'] for x in data_v],
     'location':[data_v[x]['location'] for x in data_v], 'ship_out': [data_v[x]['ship_out'] for x in data_v], 'ship_return': [data_v[x]['ship_return'] for x in data_v]}

dedupe_notary = pd.DataFrame(d_n)
dedupe_notary.index.name = 'index'
dedupe_notary.to_csv('../train_notary.csv')
dedupe_voc = pd.DataFrame(d_v)
dedupe_voc.index.name = 'index'
dedupe_voc.to_csv('../train_voc.csv')
# Out:
# HBox(children=(IntProgress(value=0, max=6832), HTML(value='')))

# %%
data_n = {}
data_v = {}
df = test
for x in notebook.tqdm(range(len(df))):
    row = df.iloc[x]
    holder = []
    if row.data_matches != 0:
        notary_date = datetime.strptime(row.datering, '%Y-%m-%d')
        
        for match in row.data_matches:
            try:
                out_date = datetime.strptime(match['date_out'], '%Y-%m-%d')
            except:
                out_date = datetime(year=1, month=1, day =1 )
            try:
                return_date = datetime.strptime(match['date_return'], '%Y-%m-%d')
            except:
                return_date = datetime(year=1, month=1, day =1 )
            if (notary_date - out_date).days in range(0, -91, -1):
                day_dif = -(notary_date - out_date).days
            elif (notary_date - return_date).days in range(0, 91):
                day_dif = (notary_date - return_date).days
            else:
                continue
            
            found_ship_out = fix_entries_ships(row, voc.iloc[match['index']], 'shipOutward')
            found_ship_return = fix_entries_ships(row, voc.iloc[match['index']], 'shipReturn')
            found_loc = fix_entries_ships(row, voc.iloc[match['index']], 'placeOfOrigin')
            found_rank = fix_entries_ships(row, voc.iloc[match['index']], 'dutch_rank')
            holder.append({'rank':found_rank, 'location':found_loc, 'found_ship_return': found_ship_return, 'found_ship_out': found_ship_out})
            
            if row.vocop_match != 0 and match['index'] == row.vocop_match[1]:
                cluster = df.iloc[x].name
            else:
                cluster = -int(voc.iloc[match['index']].VOCOP_id)
            name = str(voc.iloc[match['index']].fullNameOriginal)
            rang = str(voc.iloc[match['index']].dutch_rank)
            loc = str(voc.iloc[match['index']].placeOfOrigin)
            ship_out = str(voc.iloc[match['index']].shipOutward) 
            ship_return = str(voc.iloc[match['index']].shipReturn)
            data_v[-int(voc.iloc[match['index']].VOCOP_id)] = {'cluster_id': cluster, 'name':name, 'rank':rang, 'location':loc, 'ship_out': ship_out, 'ship_return': ship_return}
    name = row['name']
    if holder == []:
        rang = None
        location = None
        ship_out= None
        ship_return = None
    
    else:
        rang = ' | '.join(set([y.lower() for x in holder for y in x['rank']]))
        if rang == '':
            rang = None
        location = ' | '.join(set([y.lower() for x in holder for y in x['location']]))
        if location == '':
            location = None
        ship_out = ' | '.join(set([y.lower() for x in holder for y in x['found_ship_out']]))
        if ship_out == '':
            ship_return = None
        ship_return = ' | '.join(set([y.lower() for x in holder for y in x['found_ship_return']]))
        if ship_return == '':
            ship_return = None
    data_n[df.iloc[x].name] = {'cluster_id': df.iloc[x].name, 'name':name, 'rank':rang, 'location':location, 'ship_out': ship_out, 'ship_return': ship_return}

d_n = {'cluster_id': [data_n[x]['cluster_id'] for x in data_n], 'name': [data_n[x]['name'] for x in data_n], 'rank':[data_n[x]['rank'] for x in data_n],
     'location':[data_n[x]['location'] for x in data_n], 'ship_out': [data_n[x]['ship_out'] for x in data_n], 'ship_return': [data_n[x]['ship_return'] for x in data_n]}

d_v = {'cluster_id': [data_v[x]['cluster_id'] for x in data_v], 'name': [data_v[x]['name'] for x in data_v], 'rank':[data_v[x]['rank'] for x in data_v],
     'location':[data_v[x]['location'] for x in data_v], 'ship_out': [data_v[x]['ship_out'] for x in data_v], 'ship_return': [data_v[x]['ship_return'] for x in data_v]}

dedupe_notary = pd.DataFrame(d_n)
dedupe_notary.index.name = 'index'
dedupe_notary.to_csv('../test_notary.csv')
dedupe_voc = pd.DataFrame(d_v)
dedupe_voc.index.name = 'index'
dedupe_voc.to_csv('../test_voc.csv')
# Out:
# HBox(children=(IntProgress(value=0, max=2928), HTML(value='')))

# %%
len(test[test.vocop_match != 0])

# %%
16 / 26
# Out:
# 0.6153846153846154

# %%
26 * 0.68
# Out:
# 17.68

# %%
dedupe_notary[dedupe_notary.isna().ship_return == False]
# Out:
# Empty DataFrame
# Columns: [cluster_id, name, rank, location, ship_out, ship_return]
# Index: []

# %%
dedupe_voc
# Out:
#        cluster_id               name           rank     location  \
# index
# 0        -1085366       Jan de Vries       Bootsman       Jouver
# 1         -423179   Fredrik Schouten      Bottelier    Amsterdam
# 2         -784062   Christiaan Hansz        Matroos   Scheerbeek
# 3        -1118198   Christiaan Hansz    Bosschieter  Hadersleven
# 4        -1310175  Christiaan Hansen  Opperstuurman   Scheerbeek
# ...           ...                ...            ...          ...
# 1024      -346766   Pieter Pieterson    Bosschieter   Adersleben
# 1025      -796268    Pieter Pietersz        Soldaat    Holsteijn
# 1026      -842628    Pieter Pietersz    Bosschieter       Bergen
# 1027         2690   Willem Borsenius      Bottelier    Amsterdam
# 1028      -414248    Dirk van Ooijen    Bosschieter      Saerdam
#
#              ship_out     ship_return
# index
# 0      HUIS TER DUINE             nan
# 1                 Ida          RUITER
# 2          Leiderdorp       IMMAGONDA
# 3             Fortuin             nan
# 4           Immagonda       IMMAGONDA
# ...               ...             ...
# 1024     Geldermalsen             nan
# 1025       Duinenburg             nan
# 1026       Duinenburg             nan
# 1027       Sloterdijk  HUIS TER DUINE
# 1028        Bredenhof        ZAAMSLAG
#
# [1029 rows x 6 columns]

# %%
def match_neighbour(start, end, true, prev, distance):
    if true == []:
        return (start, end), prev.i
    if prev.i == len(prev.doc) - 1:
        return (start, end), prev.i
    if fuzz.ratio(true[0].lower(), prev.nbor().text.lower()) >= distance:
        return match_neighbour(start, prev.nbor().idx + len(prev.nbor()), true[1:], prev.nbor(), distance)
    else:
        return (start, end), prev.i

def match_finder(row, match, distance):

    true = match
    doc = nlp(row.text)
    locs = []
    prev = 0
    for token in doc:
        for x in true:
            if type(x) == str:
                new_token = []
                split = x.split(' ')
                for y in range(len(split)):
                    if token.i <= doc[-len(split)].i:
                        new_token.append(token.nbor(y).text)
                new_token_text = ' '.join(new_token)
                if fuzz.ratio(x.lower(), new_token_text.lower()) >= distance:
                    result = (token.idx, token.idx + len(new_token_text))
                    if result not in locs:
                        if fuzz.ratio(row.text[result[0]:result[1]].lower(), x.lower()) >= distance:
                            locs.append(result)
#                 if fuzz.ratio(split[0].lower(), token.text.lower()) >= distance:
#                     result, prev = match_neighbour(token.idx, token.idx + len(token), split[1:], token, distance)
#                     if result not in locs:
#                         if fuzz.ratio(row.text[result[0]:result[1]].lower(), x.lower()) >= distance:
#                             locs.append(result)
#     if locs == []:
#         for token in doc:
#             for x in true:
#                 if type(x) == str:
#                     split = x.split(' ')
#                     joined = ''.join(split)
#                     if fuzz.ratio(x.lower(), token.text.lower()) >= distance:
#                         result, prev = match_neighbour(token.idx, token.idx + len(token), x.lower(), token, distance)
#                         if result not in locs:
#                             if fuzz.ratio(row.text[result[0]:result[1]].lower(), x.lower()) >= distance:
#                                 locs.append(result)
    entities = [row.text[x[0]:x[1]] for x in locs]
    return entities

def fix_entries_ships(row, x, column):
    if type(x[column]) != float: 
        match = match_finder(row, [x[column]], 80) 
    else:
        match = ''
    return match

# %%
final_df[final_df.vocop_match != 0].loc[2689].text
# Out:
# "No: 295 Verklaring gecasseerd den 19e: apr: 1755GeennnOp heden den 19e: Augustes des Jaars 1755 Compareerde voor mij Jan verleij Notaris publiek bij den Ed: Hove van Holland ge admitteerd binnen Amsterdam resideerende d' E. E: Jurriaani295 den 19 Augt d' E. E. Jurriaan Bartels voor Luitenant en Willem Borzenuis voor onderstuurman nu 1754 Laast met het Schip 't huijs ten Duijnen uijt g Oostindien thuijs gekomen; En hebben Sij Compa� ranten die van genoegzamen ouderdom Sijn ter ^ mede requisitie van Jacob Meijer ^ voor onderstuurman met het gemelde Schip gerepatrieert; en ten behoeve van die 't verder mogte aangaan, getuijgt & verklaerd voornoemde Dat Sij betuigen op de thuijsreijse vang Schip van Bengale herwaerts, den opperstuurman Jan de Vrij (die nevens den requirant en den opper� meester harmanus Kluwen gemagtigdes was van den overledene Krank besoeker gerbrand ^ in duijdelijke bewoordingen Hendriksz) verscheijde malen ^ hebben horen Seggen dat de nagelate goederen van gemelde Krankbe� soeker, door hem Jan de Vrij en hermanus Kluwen op Bengale waren verkogt, en dat de Penningen die daer van waren geprovenieert, onder hem Jan de Vrij alleen waren berustende, en dat de twee andere gemagtigdens niets daer van onder Sig hadden gevende Sij betuigen voor redenen van wetenschap het vorenstaende te hebben gehoord gezien & bij� gewoord over sulks bereijd einde (des gerequireert werdende) 't Selve met Solemnele Eede te bevestigen Aldus gecasseerd binnen Amsterdam ter presentie van Johannes Dominieus Wensink en Bernardus hruijff als betuigen I Bardellstz Aots Jan Vereij Wluet er Nots: Johenne Toneneerd Wnm Cornerds Kresf"

# %%
fuzz.ratio('duine', 'duijnen')
# Out:
# 83

# %%
doc = nlp('stinky doodoo in je stinky poopoo')
for token in doc:
    new_token = ['']
    for y in range(len('Huis te Duine'.split(' '))):
        if token.i <= doc[len('Huis te Duine'.split(' '))].i:
            new_token.append(token.nbor(y).text)
    print(' '.join(new_token))
# Out:
#  stinky doodoo in
#  doodoo in je
#  in je stinky
#  je stinky poopoo

# %%
c = 0
total = 0
for x in notebook.tqdm(final_df[final_df.vocop_match != 0].itertuples(), total=final_df[final_df.vocop_match != 0].shape[0]):
    for y in x.data_matches:
        if y['index'] == x.vocop_match[1]:
            test = fix_entries_ships(x, voc.iloc[y['index']], 'shipOutward')
            if test != '':
                total += 1
            if test not in [[], '']:
                c += 1
#             else:
#                 print(x.Index)
#                 print(x.beschrijving)
#                 print(voc.iloc[y['index']]['shipOutward'])
                
                
print(c, total)
# Out:
# HBox(children=(IntProgress(value=0, max=102), HTML(value='')))
# 71 102

# %%
c = 0
total = 0
for x in notebook.tqdm(final_df[final_df.vocop_match != 0].itertuples(), total=final_df[final_df.vocop_match != 0].shape[0]):
    for y in x.data_matches:
        if y['index'] == x.vocop_match[1]:
            test = fix_entries_ships(x, voc.iloc[y['index']], 'shipReturn')
            if test != '':
                total += 1
            if test not in [[], '']:
                c += 1
                
print(c, total)
# Out:
# HBox(children=(IntProgress(value=0, max=102), HTML(value='')))
# 51 86

# %%
c = 0
total = 0
for x in notebook.tqdm(final_df[final_df.vocop_match != 0].itertuples(), total=final_df[final_df.vocop_match != 0].shape[0]):
    for y in x.data_matches:
        if y['index'] == x.vocop_match[1]:
            test = fix_entries_ships(x, voc.iloc[y['index']], 'dutch_rank')
            if test != '':
                total += 1
            if test not in [[], '']:
                c += 1
                
print(c, total)
# Out:
# HBox(children=(IntProgress(value=0, max=102), HTML(value='')))
# 38 102

# %%
c = 0
total = 0
for x in notebook.tqdm(final_df[final_df.vocop_match != 0].itertuples(), total=final_df[final_df.vocop_match != 0].shape[0]):
    for y in x.data_matches:
        if y['index'] == x.vocop_match[1]:
            test = fix_entries_ships(x, voc.iloc[y['index']], 'placeOfOrigin')
            if test != '':
                total += 1
            if test not in [[], '']:
                c += 1
                
print(c, total)
# Out:
# HBox(children=(IntProgress(value=0, max=102), HTML(value='')))
# 57 102
